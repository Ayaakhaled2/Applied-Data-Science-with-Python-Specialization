# %%
import pandas as pd

# %%
df = pd.read_csv('Admission_Predict.csv')

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
df.columns = [ col.lower().strip() for col in df.columns]

# %%
df.columns
# Out:
# Index(['serial no.', 'gre score', 'toefl score', 'university rating', 'sop',
#        'lor', 'cgpa', 'research', 'chance of admit'],
#       dtype='object')

# %%
#change the index of the dataframe

# %%
df.set_index('serial no.')
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# serial no.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# serial no.
# 1                  1             0.92
# ...

# %%
#reset the index

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index  serial no.  gre score  toefl score  university rating  sop  lor  \
# 0      0           1        337          118                  4  4.5  4.5
# 1      1           2        324          107                  4  4.0  4.5
# 2      2           3        316          104                  3  3.0  3.5
# 3      3           4        322          110                  3  3.5  2.5
# 4      4           5        314          103                  2  2.0  3.0
#
#    cgpa  research  chance of admit
# 0  9.65         1             0.92
# 1  8.87         1             0.76
# 2  8.00         1             0.72
# 3  8.67         1             0.80
# 4  8.21         0             0.65

# %%
#import df again

# %%
df = pd.read_csv('Admission_Predict.csv', index_col = 0)

# %%
df.columns = [col.lower().strip() for col in df.columns]

# %%
df['index'] = df.index

# %%
df
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit  index
# Serial No.
# 1                  1             0.92      1
# ...

# %%
df = df.set_index('gre score')

# %%
df
# Out:
#            toefl score  university rating  sop  lor  cgpa  research  \
# gre score
# 337                118                  4  4.5  4.5  9.65         1
# 324                107                  4  4.0  4.5  8.87         1
# 316                104                  3  3.0  3.5  8.00         1
# 322                110                  3  3.5  2.5  8.67         1
# 314                103                  2  2.0  3.0  8.21         0
# ...                ...                ...  ...  ...   ...       ...
# 324                110                  3  3.5  3.5  9.04         1
# 325                107                  3  3.0  3.5  9.11         1
# 330                116                  4  5.0  4.5  9.45         1
# 312                103                  3  3.5  4.0  8.78         0
# 333                117                  4  5.0  4.0  9.66         1
#
#            chance of admit  index
# gre score
# 337                   0.92      1
# 324                   0.76      2
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#      gre score  toefl score  university rating  sop  lor  cgpa  research  \
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 395        324          110                  3  3.5  3.5  9.04         1
# 396        325          107                  3  3.0  3.5  9.11         1
# 397        330          116                  4  5.0  4.5  9.45         1
# 398        312          103                  3  3.5  4.0  8.78         0
# 399        333          117                  4  5.0  4.0  9.66         1
#
#      chance of admit  index
# 0               0.92      1
# 1               0.76      2
# ...

# %%
#census.csv

# %%
df = pd.read_csv('census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.columns = [col.lower().strip() for col in df.columns]

# %%
df
# Out:
#       sumlev  region  division  state  county   stname            ctyname  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       census2010pop  estimatesbase2010  popestimate2010  ...  \
# ...

# %%
df.columns
# Out:
# Index(['sumlev', 'region', 'division', 'state', 'county', 'stname', 'ctyname',
#        'census2010pop', 'estimatesbase2010', 'popestimate2010',
#        'popestimate2011', 'popestimate2012', 'popestimate2013',
#        'popestimate2014', 'popestimate2015', 'npopchg_2010', 'npopchg_2011',
#        'npopchg_2012', 'npopchg_2013', 'npopchg_2014', 'npopchg_2015',
#        'births2010', 'births2011', 'births2012', 'births2013', 'births2014',
#        'births2015', 'deaths2010', 'deaths2011', 'deaths2012', 'deaths2013',
#        'deaths2014', 'deaths2015', 'naturalinc2010', 'naturalinc2011',
#        'naturalinc2012', 'naturalinc2013', 'naturalinc2014', 'naturalinc2015',
#        'internationalmig2010', 'internationalmig2011', 'internationalmig2012',
#        'internationalmig2013', 'internationalmig2014', 'internationalmig2015',
#        'domesticmig2010', 'domesticmig2011', 'domesticmig2012',
#        'domesticmig2013', 'domesticmig2014', 'domesticmig2015', 'netmig2010',
# ...

# %%
#return unique vals in state', 'county'
#stname	ctyname

# %%
df['stname'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df['ctyname'].unique()
# Out:
# array(['Alabama', 'Autauga County', 'Baldwin County', ..., 'Uinta County',
#        'Washakie County', 'Weston County'], dtype=object)

# %%
#set index
df = df.set_index(['stname','ctyname'])

# %%
df
# Out:
#                            sumlev  region  division  state  county  \
# stname  ctyname
# Alabama Alabama                40       3         6      1       0
#         Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            census2010pop  estimatesbase2010  popestimate2010  \
# stname  ctyname
# ...

# %%
type(df.loc['Wyoming','Teton County'])
# Out:
# C:\Users\AYA~1.KHA\AppData\Local\Temp/ipykernel_13160/1743745842.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   type(df.loc['Wyoming','Teton County'])
# pandas.core.frame.DataFrame

# %%
df.loc[[('Alabama','Baldwin County'),('Alabama','Barbour County')]]
# Out:
#                         sumlev  region  division  state  county  \
# stname  ctyname
# Alabama Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#
#                         census2010pop  estimatesbase2010  popestimate2010  \
# stname  ctyname
# Alabama Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#
#                         popestimate2011  popestimate2012  ...  \
# stname  ctyname                                           ...
# Alabama Baldwin County           186659           190396  ...
#         Barbour County            27226            27159  ...
#
#                         rdomesticmig2011  rdomesticmig2012  rdomesticmig2013  \
# stname  ctyname
# Alabama Baldwin County         14.832960         17.647293         21.845705
#         Barbour County         -4.728132         -2.500690         -7.056824
#
# ...

# %%
#handle missing

# %%
df
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
mask = df.isnull()

# %%
df_no_nulls = df.dropna()

# %%
df_no_nulls.isnull()
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0    False       False     False    False     False  False
# 1    False       False     False    False     False  False
# 4    False       False     False    False     False  False
# 5    False       False     False    False     False  False
# 6    False       False     False    False     False  False
# ..     ...         ...       ...      ...       ...    ...
# 92   False       False     False    False     False  False
# 93   False       False     False    False     False  False
# 96   False       False     False    False     False  False
# 97   False       False     False    False     False  False
# 98   False       False     False    False     False  False
#
# [81 rows x 6 columns]

# %%
df_no_nulls
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 4        8       91.32     93.64    95.00    107.41  73.89
# 5        7       95.00     92.58    93.12     97.78  68.06
# 6        8       95.05    102.99    56.25     99.07  50.00
# ..     ...         ...       ...      ...       ...    ...
# 92       7       95.60     82.28    76.88    108.33  78.33
# 93       8       87.52     91.58    56.25     71.85  85.00
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [81 rows x 6 columns]

# %%
df
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
#replace null with sclar val

# %%
df.fillna('0.0000', inplace = True)

# %%
df
# Out:
#     Prefix Assignment Tutorial Midterm TakeHome  Final
# 0        5      57.14    34.09   64.38    51.48   52.5
# 1        8      95.05   105.49    67.5    99.07  68.33
# 2        8       83.7    83.17  0.0000    63.15  48.89
# 3        7     0.0000   0.0000   49.38   105.93  80.56
# 4        8      91.32    93.64    95.0   107.41  73.89
# ..     ...        ...      ...     ...      ...    ...
# 94       8     0.0000   103.71    45.0    93.52  61.94
# 95       7     0.0000    80.54   41.25     93.7  39.72
# 96       8      89.94   102.77    87.5    90.74  87.78
# 97       7       95.6    76.13   66.25    99.81  85.56
# 98       8       63.4    97.37   73.12    72.78  77.22
#
# [99 rows x 6 columns]

# %%
df = pd.read_csv('class_grades.csv')

# %%
df.isna()
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0    False       False     False    False     False  False
# 1    False       False     False    False     False  False
# 2    False       False     False     True     False  False
# 3    False        True      True    False     False  False
# 4    False       False     False    False     False  False
# ..     ...         ...       ...      ...       ...    ...
# 94   False        True     False    False     False  False
# 95   False        True     False    False     False  False
# 96   False       False     False    False     False  False
# 97   False       False     False    False     False  False
# 98   False       False     False    False     False  False
#
# [99 rows x 6 columns]

# %%
df = df.set_index('Midterm')

# %%
df.isna()
# Out:
#          Prefix  Assignment  Tutorial  TakeHome  Final
# Midterm
# 64.38     False       False     False     False  False
# 67.50     False       False     False     False  False
# NaN       False       False     False     False  False
# 49.38     False        True      True     False  False
# 95.00     False       False     False     False  False
# ...         ...         ...       ...       ...    ...
# 45.00     False        True     False     False  False
# 41.25     False        True     False     False  False
# 87.50     False       False     False     False  False
# 66.25     False       False     False     False  False
# 73.12     False       False     False     False  False
#
# [99 rows x 5 columns]

# %%
df = df.sort_index()

# %%
df
# Out:
#          Prefix  Assignment  Tutorial  TakeHome   Final
# Midterm
# 28.12         7       93.83     57.32     77.96   45.56
# 28.75         8       87.93    108.97     87.96   47.78
# 32.50         7       89.89     57.97     85.19   51.67
# 37.50         8       87.93    106.53     97.41   28.06
# 38.75         4       92.01    102.52     86.11   49.17
# ...         ...         ...       ...       ...     ...
# 106.25        7       93.83       NaN     94.44  102.78
# 110.00        7       95.14     82.67     89.81   90.83
# NaN           8       83.70     83.17     63.15   48.89
# NaN           6         NaN     80.60       NaN   77.50
# NaN           8       93.01    104.18     96.85   67.22
#
# [99 rows x 5 columns]

# %%
df.fillna(method = 'ffill')
df.fillna(method = 'bfill')
# Out:
#          Prefix  Assignment  Tutorial  TakeHome   Final
# Midterm
# 28.12         7       93.83     57.32     77.96   45.56
# 28.75         8       87.93    108.97     87.96   47.78
# 32.50         7       89.89     57.97     85.19   51.67
# 37.50         8       87.93    106.53     97.41   28.06
# 38.75         4       92.01    102.52     86.11   49.17
# ...         ...         ...       ...       ...     ...
# 106.25        7       93.83     82.67     94.44  102.78
# 110.00        7       95.14     82.67     89.81   90.83
# NaN           8       83.70     83.17     63.15   48.89
# NaN           6       93.01     80.60     96.85   77.50
# NaN           8       93.01    104.18     96.85   67.22
#
# [99 rows x 5 columns]

# %%
#data manipulations

# %%
df = pd.read_csv('dataset.csv')

# %%
df
# Out:
#      #              President             Born  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# 11  12         Zachary Taylor     Nov 24, 1784
# 12  13       Millard Fillmore      Jan 7, 1800
# 13  14        Franklin Pierce     Nov 23, 1804
# 14  15         James Buchanan     Apr 23, 1791
# 15  16        Abraham Lincoln     Feb 12, 1809
# 16  17         Andrew Johnson     Dec 29, 1808
# 17  18       Ulysses S. Grant     Apr 27, 1822
# 18  19    Rutherford B. Hayes      Oct 4, 1822
# ...

# %%
df.columns
# Out:
# Index(['#', 'President', 'Born', 'Age atstart of presidency',
#        'Age atend of presidency', 'Post-presidencytimespan', 'Died', 'Age'],
#       dtype='object')

# %%
df['President'].tolist()
# Out:
# ['George Washington',
#  'John Adams',
#  'Thomas Jefferson',
#  'James Madison',
#  'James Monroe',
#  'John Quincy Adams',
#  'Andrew Jackson',
#  'Martin Van Buren',
#  'William H. Harrison',
#  'John Tyler',
#  'James K. Polk',
#  'Zachary Taylor',
#  'Millard Fillmore',
#  'Franklin Pierce',
#  'James Buchanan',
#  'Abraham Lincoln',
#  'Andrew Johnson',
#  'Ulysses S. Grant',
#  'Rutherford B. Hayes',
#  'James A. Garfield',
#  'Chester A. Arthur',
#  'Grover Cleveland',
#  'Benjamin Harrison',
#  'Grover Cleveland',
#  'William McKinley',
#  'Theodore Roosevelt',
#  'William H. Taft',
#  'Woodrow Wilson',
#  'Warren G. Harding',
#  'Calvin Coolidge',
#  'Herbert Hoover',
#  'Franklin D. Roosevelt',
#  'Harry S. Truman',
#  'Dwight D. Eisenhower',
#  'John F. Kennedy',
#  'Lyndon B. Johnson',
#  'Richard Nixon',
#  'Gerald Ford',
#  'Jimmy Carter',
#  'Ronald Reagan',
#  'George H. W. Bush',
#  'Bill Clinton',
#  'George W. Bush',
#  'Barack Obama']

# %%
df['first_name']= [name.split(' ')[0] for name in df['President'].tolist()]

# %%
df['last_name'] = [name.split(' ')[1] for name in df['President'].tolist()]

# %%
df
# Out:
#      #              President             Born  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# 11  12         Zachary Taylor     Nov 24, 1784
# 12  13       Millard Fillmore      Jan 7, 1800
# 13  14        Franklin Pierce     Nov 23, 1804
# 14  15         James Buchanan     Apr 23, 1791
# 15  16        Abraham Lincoln     Feb 12, 1809
# 16  17         Andrew Johnson     Dec 29, 1808
# 17  18       Ulysses S. Grant     Apr 27, 1822
# 18  19    Rutherford B. Hayes      Oct 4, 1822
# ...

# %%
df['Post-presidencytimespan'].unique()
# Out:
# array(['2\xa0years, 285\xa0days', '25\xa0years, 122\xa0days',
#        '17\xa0years, 122\xa0days', '19\xa0years, 116\xa0days',
#        '6\xa0years, 122\xa0days', '18\xa0years, 356\xa0days',
#        '8\xa0years, 96\xa0days', '21\xa0years, 142\xa0days', nan,
#        '16\xa0years, 320\xa0days', '103\xa0days',
#        '21\xa0years, 4\xa0days', '12\xa0years, 218\xa0days',
#        '7\xa0years, 89\xa0days', '6\xa0years, 149\xa0days',
#        '8\xa0years, 141\xa0days', '11\xa0years, 319\xa0days',
#        '1\xa0year, 259\xa0days', '4\xa0years, 0\xa0days[c]',
#        '8\xa0years, 9\xa0days', '11\xa0years, 112\xa0days[d]',
#        '9\xa0years, 308\xa0days', '17\xa0years, 4\xa0days',
#        '2\xa0years, 336\xa0days', '3\xa0years, 307\xa0days',
#        '31\xa0years, 230\xa0days', '19\xa0years, 341\xa0days',
#        '8\xa0years, 67\xa0days', '4\xa0years, 2\xa0days',
#        '19\xa0years, 256\xa0days', '29\xa0years, 340\xa0days',
# ...

# %%
#Post-presidencytimespan #8 years, 96 days

# %%
df
# Out:
#      #              President             Born  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# 11  12         Zachary Taylor     Nov 24, 1784
# 12  13       Millard Fillmore      Jan 7, 1800
# 13  14        Franklin Pierce     Nov 23, 1804
# 14  15         James Buchanan     Apr 23, 1791
# 15  16        Abraham Lincoln     Feb 12, 1809
# 16  17         Andrew Johnson     Dec 29, 1808
# 17  18       Ulysses S. Grant     Apr 27, 1822
# 18  19    Rutherford B. Hayes      Oct 4, 1822
# ...

# %%
#Post-presidencytimespan #8 years, 96 days

# %%
def split_days(row):
    row['years'] = row['President'].split(" ")[0]
    row['days'] = row['President'].split(" ")[-1]
    return row

# %%
df_copy = df.apply(split_days, axis = 'columns')

# %%
df_copy
# Out:
#      #              President             Born  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# 11  12         Zachary Taylor     Nov 24, 1784
# 12  13       Millard Fillmore      Jan 7, 1800
# 13  14        Franklin Pierce     Nov 23, 1804
# 14  15         James Buchanan     Apr 23, 1791
# 15  16        Abraham Lincoln     Feb 12, 1809
# 16  17         Andrew Johnson     Dec 29, 1808
# 17  18       Ulysses S. Grant     Apr 27, 1822
# 18  19    Rutherford B. Hayes      Oct 4, 1822
# ...

# %%
df
# Out:
#      #              President             Born  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# 11  12         Zachary Taylor     Nov 24, 1784
# 12  13       Millard Fillmore      Jan 7, 1800
# 13  14        Franklin Pierce     Nov 23, 1804
# 14  15         James Buchanan     Apr 23, 1791
# 15  16        Abraham Lincoln     Feb 12, 1809
# 16  17         Andrew Johnson     Dec 29, 1808
# 17  18       Ulysses S. Grant     Apr 27, 1822
# 18  19    Rutherford B. Hayes      Oct 4, 1822
# ...

# %%
#Post-presidencytimespan	 #17 years, 122 days

# %%
df
# Out:
#      #              President             Born  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# 11  12         Zachary Taylor     Nov 24, 1784
# 12  13       Millard Fillmore      Jan 7, 1800
# 13  14        Franklin Pierce     Nov 23, 1804
# 14  15         James Buchanan     Apr 23, 1791
# 15  16        Abraham Lincoln     Feb 12, 1809
# 16  17         Andrew Johnson     Dec 29, 1808
# 17  18       Ulysses S. Grant     Apr 27, 1822
# 18  19    Rutherford B. Hayes      Oct 4, 1822
# ...

# %%
df.dtypes
# Out:
# #                             int64
# President                    object
# Born                         object
# Age atstart of presidency    object
# Age atend of presidency      object
# Post-presidencytimespan      object
# Died                         object
# Age                          object
# dtype: object

# %%
def cast_str(df):
    df['Post-presidencytimespan'] = str(df['Post-presidencytimespan'])
    return df

# %%
df = df.apply(cast_str, axis = 'columns')

# %%
df.dtypes
# Out:
# #                             int64
# President                    object
# Born                         object
# Age atstart of presidency    object
# Age atend of presidency      object
# Post-presidencytimespan      object
# Died                         object
# Age                          object
# dtype: object

# %%
def split_days(df):
    #Create a new col for day
    df['day'] = df['Post-presidencytimespan'].split(',')[0]
    #create a new col for years 
    df['years'] = df['Post-presidencytimespan'].split(',')[-1]
    return df

# %%
df = df.apply(split_days, axis = 1)

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age       day      years
# 0  67 years, 295 days   2 years   285 days
# ...

# %%
#assignment

# %%
import pandas as pd
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)

# %%
obj3['California']
# Out:
# True

# %%
obj2
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj2['California'] == None
# Out:
# False

# %%
import math 
math.isnan(obj2['California'])
# Out:
# True

# %%
df
# Out:
#      #              President             Born  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# 11  12         Zachary Taylor     Nov 24, 1784
# 12  13       Millard Fillmore      Jan 7, 1800
# 13  14        Franklin Pierce     Nov 23, 1804
# 14  15         James Buchanan     Apr 23, 1791
# 15  16        Abraham Lincoln     Feb 12, 1809
# 16  17         Andrew Johnson     Dec 29, 1808
# 17  18       Ulysses S. Grant     Apr 27, 1822
# 18  19    Rutherford B. Hayes      Oct 4, 1822
# ...

# %%
df.columns
# Out:
# Index(['#', 'President', 'Born', 'Age atstart of presidency',
#        'Age atend of presidency', 'Post-presidencytimespan', 'Died', 'Age',
#        'day', 'years'],
#       dtype='object')

# %%
df.rename(mapper = lambda x : x.upper() , axis = 1 , inplace = True )

# %%
df
# Out:
#      #              PRESIDENT             BORN  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# 11  12         Zachary Taylor     Nov 24, 1784
# 12  13       Millard Fillmore      Jan 7, 1800
# 13  14        Franklin Pierce     Nov 23, 1804
# 14  15         James Buchanan     Apr 23, 1791
# 15  16        Abraham Lincoln     Feb 12, 1809
# 16  17         Andrew Johnson     Dec 29, 1808
# 17  18       Ulysses S. Grant     Apr 27, 1822
# 18  19    Rutherford B. Hayes      Oct 4, 1822
# ...

# %%
df
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# Name: #, dtype: bool

# %%
df = pd.read_csv('class_grades.csv')

# %%
df1 = df[df['Tutorial'] > 20]

# %%
df3 = df.where(df['Tutorial'] > 50)

# %%
df
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
df.drop(0)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# 5        7       95.00     92.58    93.12     97.78  68.06
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [98 rows x 6 columns]

# %%
df.drop('Prefix', axis = 1)
# Out:
#     Assignment  Tutorial  Midterm  TakeHome  Final
# 0        57.14     34.09    64.38     51.48  52.50
# 1        95.05    105.49    67.50     99.07  68.33
# 2        83.70     83.17      NaN     63.15  48.89
# 3          NaN       NaN    49.38    105.93  80.56
# 4        91.32     93.64    95.00    107.41  73.89
# ..         ...       ...      ...       ...    ...
# 94         NaN    103.71    45.00     93.52  61.94
# 95         NaN     80.54    41.25     93.70  39.72
# 96       89.94    102.77    87.50     90.74  87.78
# 97       95.60     76.13    66.25     99.81  85.56
# 98       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 5 columns]

# %%
df
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
df
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
df1.isna()
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0    False       False     False    False     False  False
# 1    False       False     False    False     False  False
# 2    False       False     False     True     False  False
# 4    False       False     False    False     False  False
# 5    False       False     False    False     False  False
# ..     ...         ...       ...      ...       ...    ...
# 94   False        True     False    False     False  False
# 95   False        True     False    False     False  False
# 96   False       False     False    False     False  False
# 97   False       False     False    False     False  False
# 98   False       False     False    False     False  False
#
# [96 rows x 6 columns]

# %%
df
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
df
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
copy_df = df[ df['Final'].gt(50)]

# %%
df = df.where( df[df['Final'] < 50])

# %%
df
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0      NaN         NaN       NaN      NaN       NaN    NaN
# 1      NaN         NaN       NaN      NaN       NaN    NaN
# 3      NaN         NaN       NaN      NaN       NaN    NaN
# 4      NaN         NaN       NaN      NaN       NaN    NaN
# 5      NaN         NaN       NaN      NaN       NaN    NaN
# ..     ...         ...       ...      ...       ...    ...
# 93     NaN         NaN       NaN      NaN       NaN    NaN
# 94     NaN         NaN       NaN      NaN       NaN    NaN
# 96     NaN         NaN       NaN      NaN       NaN    NaN
# 97     NaN         NaN       NaN      NaN       NaN    NaN
# 98     NaN         NaN       NaN      NaN       NaN    NaN
#
# [76 rows x 6 columns]

# %%
import pandas as pd
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})

# %%
s1
# Out:
# 1    Alice
# 2     Jack
# 3    Molly
# dtype: object

# %%
s1[1]
# Out:
# 'Alice'

# %%
s1.loc[1]
# Out:
# 'Alice'

# %%
s1.iloc[0]
# Out:
# 'Alice'

# %%
s2
# Out:
# Alice    1
# Jack     2
# Molly    3
# dtype: int64

# %%
s2['Alice']
# Out:
# 1

# %%
s2[0]
# Out:
# 1

# %%
s2.iloc[0]
# Out:
# 1

# %%
s3 = s1.append(s2)

# %%
s3
# Out:
# 1        Alice
# 2         Jack
# 3        Molly
# Alice        1
# Jack         2
# Molly        3
# dtype: object

# %%
#create series

# %%
s1 = {"Major" : ["math",5], "Name" : ["Alice",6] , "Age": [20,40]}

# %%
s = pd.DataFrame(s1)

# %%
s
# Out:
#   Major   Name  Age
# 0  math  Alice   20
# 1     5      6   40

# %%
s.T
# Out:
#            0   1
# Major   math   5
# Name   Alice   6
# Age       20  40
